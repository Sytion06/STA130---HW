# %% [markdown]
# ### Question 1

# %% [markdown]
# 1. Simple Linear Regression vs. Multiple Linear Regression
# - Simple Linear Regression is a model with a single predictor (independent variable) and a response (dependent variable), modeling the relationship as:
#
#   y=β0+β1x+ϵ
#
#   where y is the dependent variable, x is the single independent variable, beta0 is the intercept, beta1 is the coefficient for x, and epsilon is the error term.
#
# - Multiple Linear Regression includes two or more predictors, allowing for a model like:
#
#   y=β0+β1x1+β2x2+⋯+βkxk+ϵ
#
#   This approach provides the benefit of incorporating multiple factors that may influence y, capturing more complex relationships and generally improving prediction accuracy by accounting for additional sources of variation.
#
# 2. Continuous vs. Indicator Variables in Simple Linear Regression
# - Continuous Variables are numeric and measured on a continuous scale (e.g., age, height), which allows for regression coefficients that quantify changes in y per unit increase in the predictor.
# - Indicator Variables take on values of 0 or 1 to represent categories (e.g., boolean expression as 0 for false and 1 for true). In simple linear regression, an indicator variable shifts the predicted outcome between two groups but does not model variation within the groups.
#
# 3. Model Behavior with an Indicator Variable Added in Multiple Linear Regression
# - When a single indicator variable is added to a continuous predictor in a Multiple Linear Regression model, it effectively creates separate regression lines (intercepts) for each category represented by the indicator. This means the model can capture differences in the response variable between categories, while still using the continuous predictor for within-group variation.
#
#   For example, the model:
#   y=β0+β1x+β2D+ϵ
#
#   where D is an indicator variable (e.g., gender), would create two parallel lines (if no interaction term is added) with different intercepts for each category (e.g., male and female).
#
# 4. Adding an Interaction Between a Continuous and Indicator Variable in Multiple Linear Regression
# - Adding an interaction term between a continuous variable and an indicator variable introduces separate slopes for each category of the indicator. The model form would look like:
#   y=β0+β1x+β2D+β3(x⋅D)+ϵ
#
#   where β3 represents the interaction effect. This setup means that the relationship between y and x changes based on the category of D, allowing the model to capture distinct patterns for each group.
#
# 5. Multiple Linear Regression with Only Indicator Variables from a Categorical Variable
# - When using only indicator variables derived from a non-binary categorical variable (e.g., race with multiple categories) in a Multiple Linear Regression model, each category is typically encoded as a binary indicator in a process known as one-hot encoding. For a categorical variable with \(k\) categories, \(k-1\) binary indicators are created, with the remaining category serving as the reference.
#
#   The model then takes the form:
#   y=β0+β1D 1+β2D2+⋯+βk−1Dk−1+ϵ
#
#   Here, each coefficient βi represents the difference in the response variable relative to the reference category. This allows the model to capture different mean values for each category but does not model relationships within each group (e.g., age effects within each racial group).

# %% [markdown]
# ### Summary of Interactions for Q1
#
# Transcript Log: https://chatgpt.com/share/673007ea-cb28-8012-b694-526fcb97fff7
#
# 1. **Simple vs. Multiple Linear Regression**
#    - **Simple Linear Regression** involves a single predictor (independent variable) to model the response (dependent variable) linearly.
#    - **Multiple Linear Regression** incorporates multiple predictors, allowing the model to capture more complex relationships and improve accuracy by accounting for multiple sources of variation. This is useful when the response variable depends on several factors.
#
# 2. **Continuous vs. Indicator Variables in Simple Linear Regression**
#    - **Continuous variables** are numeric and allow regression coefficients to quantify changes in the response variable per unit increase in the predictor.
#    - **Indicator variables** are binary (0 or 1) and represent categories. In simple linear regression, they shift the predicted outcome between categories, without capturing variation within categories.
#
# 3. **Adding an Indicator Variable in Multiple Linear Regression**
#    - Introducing a **single indicator variable** along with a continuous predictor in multiple linear regression results in separate intercepts for each category represented by the indicator. This enables the model to capture between-group differences while using the continuous predictor for within-group variation.
#
# 4. **Interaction Between a Continuous and Indicator Variable in Multiple Linear Regression**
#    - Including an **interaction term** between a continuous and an indicator variable allows for distinct slopes for each category. This means the relationship between the response variable and the continuous predictor can differ based on the category of the indicator variable, adding flexibility to the model.
#
# 5. **Multiple Linear Regression with Only Indicator Variables from a Non-Binary Categorical Variable**
#    - When modeling only **indicator variables derived from a categorical variable** (using one-hot encoding), each category is encoded as a binary variable. The model captures mean differences across categories, with one category serving as the reference, allowing discrete group differences but no within-group continuous variation.

# %% [markdown]
# ### Question 2

# %% [markdown]
# 1.
#
# Without Interaction:
#
# A model without interaction assumes the effect of TV and online advertising on sales is independent:
#
# Sales=𝛽0+𝛽1⋅TV+𝛽2⋅Online
#
# Here, 𝛽0 is the intercept, representing baseline sales with no advertising. 𝛽1 represents the expected change in sales for each additional unit spent on TV advertising, assuming the online ad spend is fixed. 𝛽2 is the change in sales for each additional unit spent on online advertising, assuming the TV ad spend is fixed.
#
# With Interaction:
#
# When we introduce an interaction term, we acknowledge that the effectiveness of TV advertising may change depending on the online advertising budget and vice versa. This model looks like:
#
# Sales=𝛽0+𝛽1⋅TV+𝛽2⋅Online+𝛽3⋅(TV×Online)
#
# The 𝛽3 term captures the interaction effect, indicating how the effect of spending on TV ads changes with the level of online advertising.
#
# Predicting with the Models and Differences in Outcomes:
#
# Without interaction: Predictions from this model would be straightforward; sales increase linearly with spending on TV and online ads, with each medium contributing independently to the outcome.
# With interaction: This model allows for a compounding or diminishing effect based on simultaneous investments in both advertising types. If 𝛽3 is positive, there may be synergy; the more is spent on both, the higher the combined impact on sales. If 𝛽3 is negative, then spending on one type of advertising reduces the effectiveness of the other.

# %% [markdown]
# 2.
#
# When we categorize advertising budgets into "High" or "Low," the models change to reflect binary predictor variables:
#
# Without Interaction (Binary Predictors):
# With binary variables, let TVHigh and Online High be indicator variables for high budget categories:
#
# Sales=𝛽0+𝛽1⋅TVHigh+𝛽2⋅OnlineHigh
#
# 𝛽1 now represents the increase in sales when TV advertising moves from low to high, assuming online advertising is low.
# 𝛽2 represents the increase in sales when online advertising moves from low to high, assuming TV advertising is low.
#
# With Interaction (Binary Predictors):
# Adding an interaction term allows us to model the combined effect when both budgets are high:
#
# Sales=𝛽0+𝛽1⋅TVHigh+𝛽2⋅OnlineHigh+𝛽3⋅(TVHigh×OnlineHigh)
#
# Here,
# 𝛽3 represents the additional effect on sales when both advertising budgets are high, beyond what would be expected from either being high alone.
#
# Predicting with Binary Models
# Without interaction: Predictions assume that any increase in sales is simply the additive effect of high budgets in TV and online advertising.
# With interaction: This model allows for a synergistic or antagonistic effect, reflecting a more nuanced impact on sales based on the simultaneous use of high budgets across both advertising channels.

# %% [markdown]
# ### Summary of Interaction for Q2
#
# Transcript Log: https://chatgpt.com/share/67311508-229c-8012-881c-929515dc9c1e
#
# 1. **Identifying Variables and Interaction Effects**
#    - We discussed a scenario in which a company selling sports equipment aims to predict sales based on TV and online advertising budgets.
#    - **Outcome variable**: Sales.
#    - **Predictor variables**: Advertising budgets for TV and online platforms.
#    - We explored the possibility of an **interaction effect** between the two predictors, where the impact of one advertising type could depend on the level of spending on the other.
#
# 2. **Formulating Linear Models with and without Interaction**
#    - We examined a **model without interaction**:
#      \[
#      \text{Sales} = \beta_0 + \beta_1 \cdot \text{TV} + \beta_2 \cdot \text{Online}
#      \]
#      where each predictor contributes independently to sales.
#    - We then discussed a **model with interaction**:
#      \[
#      \text{Sales} = \beta_0 + \beta_1 \cdot \text{TV} + \beta_2 \cdot \text{Online} + \beta_3 \cdot (\text{TV} \times \text{Online})
#      \]
#      to capture any synergistic or antagonistic effects between the two advertising channels.
#    - **Prediction explanation**: For the non-interaction model, sales increase linearly with each ad spend, independently. With interaction, the combined effect could lead to a compounding or diminishing effect, depending on the \(\beta_3\) coefficient.
#
# 3. **Modifying the Models for Binary Predictor Variables**
#    - We adapted both models to consider binary budget categories ("High" or "Low") instead of continuous spending:
#      - **Without interaction (binary)**:
#        \[
#        \text{Sales} = \beta_0 + \beta_1 \cdot \text{TV}_\text{High} + \beta_2 \cdot \text{Online}_\text{High}
#        \]
#      - **With interaction (binary)**:
#        \[
#        \text{Sales} = \beta_0 + \beta_1 \cdot \text{TV}_\text{High} + \beta_2 \cdot \text{Online}_\text{High} + \beta_3 \cdot (\text{TV}_\text{High} \times \text{Online}_\text{High})
#        \]
#    - **Prediction explanation**: In the binary model without interaction, high TV and online ad budgets impact sales independently. With interaction, a combined high budget in both channels could lead to additional effects not captured by their separate impacts.

# %% [markdown]
# ### Question 3

# %%
import pandas as pd
import statsmodels.formula.api as smf
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

df = pd.read_csv('CSCS_data_anon.csv').fillna('None')

df['freq'] = (df['CONNECTION_preferred_frequency_one_on_one'] != 'None').astype(int)
# Out:
# /tmp/ipykernel_70/2276970184.py:7: DtypeWarning: Columns (408,1001,1002,1006,1007,1008,1080,1113,1115,1116,1117,1118,1119,1120,1121,1124,1125,1126,1127,1128,1213,1214,1215,1216,1217,1218,1342,1343,1344,1345,1346,1347,1348,1349,1390,1391,1393,1463,1549,1552,1555,1558,1561) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('CSCS_data_anon.csv').fillna('None')
# /tmp/ipykernel_70/2276970184.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['freq'] = (df['CONNECTION_preferred_frequency_one_on_one'] != 'None').astype(int)

# %%
linear_model_specification_formula = \
'freq ~ WELLNESS_life_satisfaction + C(WELLNESS_self_rated_mental_health)'
log_reg_fit = smf.logit(linear_model_specification_formula, data=df).fit()
log_reg_fit.summary()
# Out:
# /opt/conda/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...
#          Current function value: 0.196207
#          Iterations: 35
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   freq   No. Observations:                11431
# Model:                          Logit   Df Residuals:                    11414
# Method:                           MLE   Df Model:                           16
# Date:                Thu, 14 Nov 2024   Pseudo R-squ.:                 0.05807
# Time:                        00:31:40   Log-Likelihood:                -2242.8
# converged:                      False   LL-Null:                       -2381.1
# Covariance Type:            nonrobust   LLR p-value:                 1.815e-49
# ...

# %%
import numpy as np
import plotly.graph_objects as go

# Simulate data range for the continuous predictor (e.g., WELLNESS_life_satisfaction)
np.random.seed(42)
n = 100
continuous_variable = np.linspace(1, 10, n)  # Simulate WELLNESS_life_satisfaction across its range
binary_variable = np.random.choice([0, 1], size=n)  # Simulate a binary indicator (e.g., WELLNESS_self_rated_mental_health)

# Extract coefficients from the logistic model output provided
intercept = -3.3281
slope_continuous = 0.3969  # Example coefficient for WELLNESS_life_satisfaction (mid-range estimate)
slope_binary = 0.3837  # Example coefficient for binary indicator (Fair mental health)
interaction_effect = 0.7032  # Example interaction effect for continuous * binary

# Generate response variables for both models
# Additive model: Response ~ Intercept + slope_continuous * Continuous Predictor + slope_binary * Binary Predictor + noise
random_noise = np.random.normal(0, 1, n)  # Random noise for realism in the data points
response_additive = intercept + slope_continuous * continuous_variable + slope_binary * binary_variable + random_noise

# Synergistic model: Response ~ Intercept + slope_continuous * Continuous Predictor + slope_binary * Binary Predictor + interaction_effect * (Continuous Predictor * Binary Predictor) + noise
response_synergistic = (intercept + slope_continuous * continuous_variable + 
                        slope_binary * binary_variable + interaction_effect * continuous_variable * binary_variable + 
                        random_noise)

# Best fit lines (calculated without noise) for the two models
# Additive model fit lines
fitted_line_additive_0 = intercept + slope_continuous * continuous_variable  # for Binary Indicator = 0
fitted_line_additive_1 = intercept + slope_continuous * continuous_variable + slope_binary  # for Binary Indicator = 1

# Synergistic model fit lines
fitted_line_synergistic_0 = intercept + slope_continuous * continuous_variable  # for Binary Indicator = 0
fitted_line_synergistic_1 = (intercept + slope_continuous * continuous_variable + 
                             slope_binary + interaction_effect * continuous_variable)  # for Binary Indicator = 1

# Prepare data for plotting
df_additive = pd.DataFrame({
    'Continuous Predictor': continuous_variable,
    'Binary Predictor': binary_variable,
    'Response': response_additive
})

df_synergistic = pd.DataFrame({
    'Continuous Predictor': continuous_variable,
    'Binary Predictor': binary_variable,
    'Response': response_synergistic
})

# Plot Additive Model
fig1 = go.Figure()
# Scatter plot of simulated data points
fig1.add_trace(go.Scatter(x=df_additive[df_additive['Binary Predictor'] == 0]['Continuous Predictor'],
                          y=df_additive[df_additive['Binary Predictor'] == 0]['Response'],
                          mode='markers', name='Binary Predictor = 0', marker=dict(color='blue')))
fig1.add_trace(go.Scatter(x=df_additive[df_additive['Binary Predictor'] == 1]['Continuous Predictor'],
                          y=df_additive[df_additive['Binary Predictor'] == 1]['Response'],
                          mode='markers', name='Binary Predictor = 1', marker=dict(color='red')))
# Add best fit lines
fig1.add_trace(go.Scatter(x=continuous_variable, y=fitted_line_additive_0, mode='lines',
                          name='Additive Model Fit (Binary = 0)', line=dict(color='blue', dash='dash')))
fig1.add_trace(go.Scatter(x=continuous_variable, y=fitted_line_additive_1, mode='lines',
                          name='Additive Model Fit (Binary = 1)', line=dict(color='red', dash='dash')))
fig1.update_layout(title="Additive Model: Continuous + Binary Predictor",
                   xaxis_title="Continuous Predictor", yaxis_title="Response")

# Plot Synergistic Model
fig2 = go.Figure()
# Scatter plot of simulated data points
fig2.add_trace(go.Scatter(x=df_synergistic[df_synergistic['Binary Predictor'] == 0]['Continuous Predictor'],
                          y=df_synergistic[df_synergistic['Binary Predictor'] == 0]['Response'],
                          mode='markers', name='Binary Predictor = 0', marker=dict(color='blue')))
fig2.add_trace(go.Scatter(x=df_synergistic[df_synergistic['Binary Predictor'] == 1]['Continuous Predictor'],
                          y=df_synergistic[df_synergistic['Binary Predictor'] == 1]['Response'],
                          mode='markers', name='Binary Predictor = 1', marker=dict(color='red')))
# Add best fit lines
fig2.add_trace(go.Scatter(x=continuous_variable, y=fitted_line_synergistic_0, mode='lines',
                          name='Synergistic Model Fit (Binary = 0)', line=dict(color='blue', dash='dash')))
fig2.add_trace(go.Scatter(x=continuous_variable, y=fitted_line_synergistic_1, mode='lines',
                          name='Synergistic Model Fit (Binary = 1)', line=dict(color='red', dash='dash')))
fig2.update_layout(title="Synergistic Model: Continuous * Binary Predictor",
                   xaxis_title="Continuous Predictor", yaxis_title="Response")

# Show plots
fig1.show(renderer = 'png')
fig2.show(renderer = 'png')

# %% [markdown]
# ### Summary of Interactions for Q3
#
# Transcript Log: https://chatgpt.com/share/67312077-81bc-8012-bc14-87f316f8692d
#
# 1. **Logistic Regression with Categorical Predictors**:
#    - You wanted to perform a logistic regression using `statsmodels` on data from the Canadian Social Connection Survey (CSCS) dataset. The model used `WELLNESS_life_satisfaction` (as a categorical predictor) and `WELLNESS_self_rated_mental_health` (also categorical) to predict `freq` (a binary indicator).
#    - I provided guidance on how to specify categorical variables in `statsmodels` using `C()` to ensure the model treats these predictors appropriately as categorical.
#    - We reviewed the model summary, focusing on the statistical significance and interpretation of each coefficient, particularly for different levels of `WELLNESS_life_satisfaction` and `WELLNESS_self_rated_mental_health`.
#
# 2. **Visualization of Logistic Regression Results as Linear Model Fit Lines**:
#    - Although this was a logistic regression model, you requested a simplified approach to visualize it as if it were a multivariate linear regression with continuous and binary predictors.
#    - To illustrate the main and interaction effects, I proposed plotting "best fit" lines for:
#      - (a) **Additive Specification**: where both predictors (one continuous, one binary) have independent effects.
#      - (b) **Synergistic Specification**: where an interaction term between the continuous and binary predictors models the effect of one predictor depending on the level of the other.
#    - I provided Python code to simulate data points with random noise, construct fitted lines based on model coefficients, and visualize the results using `plotly`. The plots allowed you to assess whether the interaction term (synergistic effect) was necessary for capturing variations across binary categories in the continuous predictor's effect.
#
# 3. **Interpretation and Necessity of the Interaction Term**:
#    - We discussed how the additive model assumes parallel lines (independent effects), whereas the synergistic model allows for differing slopes based on the binary indicator. The necessity of the interaction term can be judged by the relative difference in slopes across binary levels. If the lines are nearly parallel, the interaction term may be unnecessary, while a clear divergence would indicate its importance.

# %% [markdown]
# ### Question 4

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
# fail https://github.com/KeithGalli/pandas/blob/master/pokemon_data.csv
pokeaman = pd.read_csv(url) 
pokeaman
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
import statsmodels.formula.api as smf

model1_spec = smf.ols(formula='HP ~ Q("Sp. Def") + C(Generation)', data=pokeaman)
model2_spec = smf.ols(formula='HP ~ Q("Sp. Def") + C(Generation) + Q("Sp. Def"):C(Generation)', data=pokeaman)
model2_spec = smf.ols(formula='HP ~ Q("Sp. Def") * C(Generation)', data=pokeaman)

model2_fit = model2_spec.fit()
model2_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     15.27
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           3.50e-27
# Time:                        00:31:41   Log-Likelihood:                -3649.4
# No. Observations:                 800   AIC:                             7323.
# Df Residuals:                     788   BIC:                             7379.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# An R-squared value of 0.176 means that only 17.6% of the variability in HP is accounted for by the predictors in the model. This suggests that a substantial portion (82.4%) of the variation in HP is unexplained, implying there are other important factors influencing HP that are not included in this model.The fact that many coefficients are larger than 10 and have strong evidence against the null hypothesis suggests that the predictors, such as Sp. Def and Generation, have a statistically significant impact on HP. However, they are not sufficient to account for the majority of the variability. There may be many other unobserved or omitted factors influencing HP, and the model's limited explanatory power (R-squared) reflects this.
#
# In other words, the predictors are meaningful (e.g., Sp. Def, Generation) and have strong relationships with HP, but the overall model (as a whole) doesn't capture most of the variability in HP.

# %% [markdown]
# ### Summary of Interactions for Q4
#
# Transcript Log: https://chatgpt.com/share/67354523-4748-8012-9584-18ddade4d40f
#
# 1. **Initial Query on Model Fit and Coefficients**:
#    - You were analyzing an **OLS regression model** for predicting `HP` in a dataset and observed an **R-squared value of 0.176**, indicating that only 17.6% of the variability in `HP` was explained by the model.
#    - At the same time, several **coefficients** in the model were large (some greater than 10) and **highly significant**, showing strong evidence against the null hypothesis of "no effect." This led to an apparent contradiction where the model had low explanatory power (R-squared) but significant predictor coefficients.
#
# 2. **Explanation of the Apparent Contradiction**:
#    - I explained that **R-squared** measures the overall explanatory power of the model—how much of the total variability in `HP` the model can account for. A low R-squared value suggests that there are other factors influencing `HP` that were not included in the model.
#    - On the other hand, **large and significant coefficients** (indicated by high t-values and low p-values) demonstrate that certain predictors (such as `Sp. Def` and `Generation`) have a statistically meaningful relationship with `HP`.
#    - Therefore, while the model doesn’t capture much of the overall variability in `HP`, the predictors included are still **meaningful** and **significantly related to `HP`**, showing that these factors are important but likely not sufficient to fully explain `HP`.
#
# 3. **Detailed Analysis of Model Output**:
#    - I walked you through specific output details, such as the **F-statistic** and its p-value, which indicated that the model as a whole was statistically significant despite a low R-squared.
#    - We discussed how **low R-squared and high significance** of individual predictors can coexist, particularly when other influential factors are omitted from the model.
#    - Additional diagnostic metrics like **Durbin-Watson** and **Omnibus** test values indicated possible issues with residuals and normality assumptions, suggesting areas for potential model refinement.
#
# 4. **Key Insights on the Contradiction**:
#    - The contradiction between low R-squared and significant coefficients reflects that while `Sp. Def`, `Generation`, and their interactions affect `HP`, these predictors are **not sufficient** to capture all influences on `HP`, hence the low R-squared.
#    - This outcome is common in cases where predictors are **statistically significant** but do not **fully explain** the complexity of the dependent variable, often due to **omitted variables**, **limited model complexity**, or **assumptions of linearity**.

# %% [markdown]
# ### Question 5

# %%
import numpy as np
from sklearn.model_selection import train_test_split

fifty_fifty_split_size = int(pokeaman.shape[0]*0.5)

# Replace "NaN" (in the "Type 2" column with "None")
pokeaman.fillna('None', inplace=True)

np.random.seed(130)
pokeaman_train,pokeaman_test = \
  train_test_split(pokeaman, train_size=fifty_fifty_split_size)
pokeaman_train
# Out:
#        #                     Name   Type 1   Type 2  HP  Attack  Defense  \
# 370  338                  Solrock     Rock  Psychic  70      95       85
# 6      6                Charizard     Fire   Flying  78      84       78
# 242  224                Octillery    Water     None  75     105       75
# 661  600                    Klang    Steel     None  60      80       95
# 288  265                  Wurmple      Bug     None  45      45       35
# ..   ...                      ...      ...      ...  ..     ...      ...
# 522  471                  Glaceon      Ice     None  65      60      110
# 243  225                 Delibird      Ice   Flying  45      55       45
# 797  720      HoopaHoopa Confined  Psychic    Ghost  80     110       60
# 117  109                  Koffing   Poison     None  40      65       95
# 409  373  SalamenceMega Salamence   Dragon   Flying  95     145      130
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# The code above first replace all the missing values in pokeaman dataset with None, and then split it into two distinct dataset, pokeman_train and pokeaman_test, each representing 50% of the rows of the original pokeaman dataset.

# %%
model_spec3 = smf.ols(formula='HP ~ Attack + Defense', 
                      data=pokeaman_train)
model3_fit = model_spec3.fit()
model3_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     34.40
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           1.66e-14
# Time:                        00:31:41   Log-Likelihood:                -1832.6
# No. Observations:                 400   AIC:                             3671.
# Df Residuals:                     397   BIC:                             3683.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     42.5882      3.580     11.897      0.000      35.551      49.626
# ...

# %% [markdown]
# The above code fits a linear regression model to predict Pokémon HP based on Attack and Defense stats and then prints a summary of the model's performance and fit details.

# %%
yhat_model3 = model3_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model3_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model3)[0,1]**2)
# Out:
# 'In sample' R-squared:     0.14771558304519894
# 'Out of sample' R-squared: 0.21208501873920738

# %% [markdown]
# This code calculates and prints the in-sample and out-of-sample 𝑅^2 values for the linear regression model model3_fit. The code `yhat_model3 = model3_fit.predict(pokeaman_test)` uses the fitted model `model3_fit` to predict HP values (`yhat_model3`) for the `pokeaman_test` dataset, which was not used to fit the model. These predictions represent the out-of-sample predictions for the model.
# `y = pokeaman_test.HP` extracts the actual HP values from `pokeaman_test`, so that these can be compared with the predictions (yhat_model3).

# %%
model4_linear_form = 'HP ~ Attack * Defense * Speed * Legendary'
model4_linear_form += ' * Q("Sp. Def") * Q("Sp. Atk")'
# DO NOT try adding '* C(Generation) * C(Q("Type 1")) * C(Q("Type 2"))'
# That's 6*18*19 = 6*18*19 possible interaction combinations...
# ...a huge number that will blow up your computer

model4_spec = smf.ols(formula=model4_linear_form, data=pokeaman_train)
model4_fit = model4_spec.fit()
model4_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.369
# Method:                 Least Squares   F-statistic:                     4.764
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           4.23e-21
# Time:                        00:31:41   Log-Likelihood:                -1738.6
# No. Observations:                 400   AIC:                             3603.
# Df Residuals:                     337   BIC:                             3855.
# Df Model:                          62
# Covariance Type:            nonrobust
# ...
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# This code fits an extensive model with multiple main effects and high-order interactions, then displays a summary of the results to evaluate the predictive power of the included features on HP.

# %%
yhat_model4 = model4_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model4_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model4)[0,1]**2)
# Out:
# 'In sample' R-squared:     0.46709442115833855
# 'Out of sample' R-squared: 0.002485342598992873

# %% [markdown]
# This code calculates the in-sample and out-of-sample 𝑅^2 values for the complex regression model model4_fit, which was fitted on the training data (pokeaman_train).
# - In-sample R^2 measures how well the model fits the training data (pokeaman_train).
# - Out-of-sample R^2measures how well the model predicts the test data (pokeaman_test), assessing the model's performance on unseen data.

# %% [markdown]
# ### Question 6

# %%
# "Cond. No." WAS 343.0 WITHOUT to centering and scaling
model3_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     34.40
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           1.66e-14
# Time:                        00:31:41   Log-Likelihood:                -1832.6
# No. Observations:                 400   AIC:                             3671.
# Df Residuals:                     397   BIC:                             3683.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     42.5882      3.580     11.897      0.000      35.551      49.626
# ...

# %%
from patsy import center, scale

model3_linear_form_center_scale = \
  'HP ~ scale(center(Attack)) + scale(center(Defense))' 
model_spec3_center_scale = smf.ols(formula=model3_linear_form_center_scale,
                                   data=pokeaman_train)
model3_center_scale_fit = model_spec3_center_scale.fit()
model3_center_scale_fit.summary()
# "Cond. No." is NOW 1.66 due to centering and scaling
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     34.40
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           1.66e-14
# Time:                        00:31:42   Log-Likelihood:                -1832.6
# No. Observations:                 400   AIC:                             3671.
# Df Residuals:                     397   BIC:                             3683.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
model4_linear_form_CS = 'HP ~ scale(center(Attack)) * scale(center(Defense))'
model4_linear_form_CS += ' * scale(center(Speed)) * Legendary' 
model4_linear_form_CS += ' * scale(center(Q("Sp. Def"))) * scale(center(Q("Sp. Atk")))'
# Legendary is an indicator, so we don't center and scale that

model4_CS_spec = smf.ols(formula=model4_linear_form_CS, data=pokeaman_train)
model4_CS_fit = model4_CS_spec.fit()
model4_CS_fit.summary().tables[-1]  # Cond. No. is 2,250,000,000,000,000
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# Just as the condition number was very bad to start with
model4_fit.summary().tables[-1]  # Cond. No. is 12,000,000,000,000,000
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# The model formula (model4_linear_form) expands to generate a large number of new predictor variables due to interaction terms. These terms represent combinations of features (e.g., Attack * Defense, Speed * Sp. Atk * Sp. Def) and create many columns in the design matrix (model4_spec.exog). This matrix is used in regression to predict HP by modeling how each predictor (original or interaction) contributes to the outcome.
#
# The problem with this setup is multicollinearity—a situation where predictor variables in the design matrix are highly correlated (often visible via np.corrcoef(model4_spec.exog)). High multicollinearity inflates the Condition Number, leading to numerical instability: coefficients become sensitive to small changes in the data and hard to estimate precisely. Consequently, predictions on new (out-of-sample) data can become unreliable because the model, while complex, may "overfit" patterns specific to the training data rather than capturing general relationships.

# %% [markdown]
# ### Question 7

# %%
model5_linear_form = 'HP ~ Attack + Defense + Speed + Legendary'
model5_linear_form += ' + Q("Sp. Def") + Q("Sp. Atk")'
model5_linear_form += ' + C(Generation) + C(Q("Type 1")) + C(Q("Type 2"))'

model5_spec = smf.ols(formula=model5_linear_form, data=pokeaman_train)
model5_fit = model5_spec.fit()
model5_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     4.948
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           9.48e-19
# Time:                        00:31:42   Log-Likelihood:                -1765.0
# No. Observations:                 400   AIC:                             3624.
# Df Residuals:                     353   BIC:                             3812.
# Df Model:                          46
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
yhat_model5 = model5_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model5_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model5)[0,1]**2)
# Out:
# 'In sample' R-squared:     0.3920134083531893
# 'Out of sample' R-squared: 0.30015614488652215

# %%
# Here's something a little more reasonable...
model6_linear_form = 'HP ~ Attack + Speed + Q("Sp. Def") + Q("Sp. Atk")'
# And here we'll add the significant indicators from the previous model
# https://chatgpt.com/share/81ab88df-4f07-49f9-a44a-de0cfd89c67c
model6_linear_form += ' + I(Q("Type 1")=="Normal")'
model6_linear_form += ' + I(Q("Type 1")=="Water")'
model6_linear_form += ' + I(Generation==2)'
model6_linear_form += ' + I(Generation==5)'

model6_spec = smf.ols(formula=model6_linear_form, data=pokeaman_train)
model6_fit = model6_spec.fit()
model6_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.333
# Model:                            OLS   Adj. R-squared:                  0.319
# Method:                 Least Squares   F-statistic:                     24.36
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           2.25e-30
# Time:                        00:31:42   Log-Likelihood:                -1783.6
# No. Observations:                 400   AIC:                             3585.
# Df Residuals:                     391   BIC:                             3621.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# ...

# %%
yhat_model6 = model6_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model6_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model6)[0,1]**2)
# Out:
# 'In sample' R-squared:     0.3326310334310908
# 'Out of sample' R-squared: 0.29572460427079933

# %%
# And here's a slight change that seems to perhaps improve prediction...
model7_linear_form = 'HP ~ Attack * Speed * Q("Sp. Def") * Q("Sp. Atk")'
model7_linear_form += ' + I(Q("Type 1")=="Normal")'
model7_linear_form += ' + I(Q("Type 1")=="Water")'
model7_linear_form += ' + I(Generation==2)'
model7_linear_form += ' + I(Generation==5)'

model7_spec = smf.ols(formula=model7_linear_form, data=pokeaman_train)
model7_fit = model7_spec.fit()
model7_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.347
# Method:                 Least Squares   F-statistic:                     12.16
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           4.20e-29
# Time:                        00:31:42   Log-Likelihood:                -1769.5
# No. Observations:                 400   AIC:                             3579.
# Df Residuals:                     380   BIC:                             3659.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
yhat_model7 = model7_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model7_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model7)[0,1]**2)
# Out:
# 'In sample' R-squared:     0.37818209127432456
# 'Out of sample' R-squared: 0.35055389205977444

# %%
# And here's a slight change that seems to perhas improve prediction...
model7_linear_form_CS = 'HP ~ scale(center(Attack)) * scale(center(Speed))'
model7_linear_form_CS += ' * scale(center(Q("Sp. Def"))) * scale(center(Q("Sp. Atk")))'
# We DO NOT center and scale indicator variables
model7_linear_form_CS += ' + I(Q("Type 1")=="Normal")'
model7_linear_form_CS += ' + I(Q("Type 1")=="Water")'
model7_linear_form_CS += ' + I(Generation==2)'
model7_linear_form_CS += ' + I(Generation==5)'

model7_CS_spec = smf.ols(formula=model7_linear_form_CS, data=pokeaman_train)
model7_CS_fit = model7_CS_spec.fit()
model7_CS_fit.summary().tables[-1] 
# "Cond. No." is NOW 15.4 due to centering and scaling
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# "Cond. No." WAS 2,340,000,000 WITHOUT to centering and scaling
model7_fit.summary().tables[-1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# **Here is quick summary of the development process:**
#
# From model3 to model4: Focus on adding interaction effects and additional predictors (such as Sp. Def and Sp. Atk).
#
# From model4 to model5: Simplify the model by removing higher-order interactions and focusing on the most relevant continuous and categorical predictors.
#
# From model5 to model6: Introduce indicator variables for specific categories (e.g., Type 1 and Generation) to capture categorical effects without increasing model complexity.
#
# From model6 to model7: Reintroduce interaction terms to capture more complex relationships between predictors, enhancing the model’s predictive power.

# %% [markdown]
# The principles behind the progression of the models can be summarized as follows:
#
# 1. Start Simple and Build Up Complexity
#    - Rationale: Begin with a basic model to establish a baseline and understand the core relationships between the dependent variable (HP) and a few key predictors (e.g., `Attack` and `Defense` in `model3`).
#    - Principle: Simplicity first – Simple models are easier to interpret and help identify the most influential predictors before adding more complexity.
#
# 2. Incorporate Interactions for Better Accuracy
#    - Rationale: As the initial model reveals the basic relationships, the next step is to explore interaction effects (e.g., `Attack * Defense`) to capture how the effect of one predictor changes depending on the values of another. This helps the model account for more complex, real-world relationships between predictors.
#    - Principle: Model complexity should increase only when necessary – Add complexity (like interactions) when the simpler model fails to capture enough of the data's variability.
#
# 3. Simplify and Focus on Key Predictors
#    - Rationale: After introducing interactions, the next step is to simplify the model by removing unnecessary terms that might lead to overfitting (e.g., higher-order interactions). Instead, focus on the most relevant variables and predictors that have the strongest relationship with the outcome (e.g., `Type 1`, `Generation` indicators).
#    - Principle: Occam's Razor – A simpler model with fewer predictors is often more interpretable and generalizes better, reducing the risk of overfitting.
#
# 4. Reintroduce Complexities Only If Needed
#    - Rationale: After simplifying, if the predictive accuracy does not improve or starts to degrade, reintroduce interactions between predictors to capture more intricate relationships. This can help improve model performance, especially if the simpler models missed important patterns.
#    - Principle: Balance between complexity and generalization – Adding complexity should be a measured decision aimed at improving prediction, not just fitting the training data more closely.
#
# 5. Handle Multicollinearity and Improve Stability
#    - Rationale: In some models, collinearity between predictors can lead to instability (e.g., large condition numbers in the model summary). Techniques like centering and scaling the predictors can help reduce multicollinearity, making the model more stable and interpretable.
#    - Principle: Numerical stability – A model that suffers from multicollinearity may produce unreliable estimates. Addressing this improves both model stability and predictive accuracy.

# %% [markdown]
# ### Question 8

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split

# Define the model specification (adjust based on your previous models)
model_linear_form = 'HP ~ Attack + Defense + Speed + Legendary + Q("Sp. Def") + Q("Sp. Atk")'

# Initialize lists to store the performance metrics
in_sample_r_squared = []
out_sample_r_squared = []

# Set the number of iterations (e.g., 100 for robust testing)
num_iterations = 100

for i in range(num_iterations):
    # Split the data (train-test) randomly without fixing the seed each time
    pokeaman_train, pokeaman_test = train_test_split(pokeaman, train_size=0.5)
    
    # Define the model
    model_spec = smf.ols(formula=model_linear_form, data=pokeaman_train)
    
    # Fit the model
    model_fit = model_spec.fit()
    
    # In-sample R-squared (on training data)
    in_sample_r_squared.append(model_fit.rsquared)
    
    # Out-of-sample R-squared (on test data)
    yhat = model_fit.predict(pokeaman_test)
    y = pokeaman_test.HP
    out_sample_r_squared.append(np.corrcoef(y, yhat)[0, 1] ** 2)

# Convert lists to arrays for easier analysis
in_sample_r_squared = np.array(in_sample_r_squared)
out_sample_r_squared = np.array(out_sample_r_squared)

# Visualization
plt.figure(figsize=(12, 6))
plt.plot(in_sample_r_squared, label="In-sample R-squared", color='blue', alpha=0.7)
plt.plot(out_sample_r_squared, label="Out-of-sample R-squared", color='red', alpha=0.7)
plt.title("Model Performance: In-sample vs. Out-of-sample R-squared over 100 Iterations")
plt.xlabel("Iteration")
plt.ylabel("R-squared")
plt.legend()
plt.show()

# %% [markdown]
# Explanation of the Code:
# 1. **Model Definition**: The model formula (`model_linear_form`) is specified with relevant features such as `Attack`, `Defense`, `Speed`, and other categorical features like `Legendary` and `Type`.
# 2. **Random Train-Test Split**: In each iteration, the dataset is split randomly into training and test sets. Since `np.random.seed(130)` is **not** fixed within the loop, the splits will differ in each iteration, reflecting real-world randomness in data partitioning.
# 3. **Model Fitting**: For each random split, the model is fitted to the training data (`pokeaman_train`).
# 4. **Performance Metrics**:
#    - **In-sample R-squared**: This is the R-squared value on the training data, which indicates how well the model explains the variance in the training set.
#    - **Out-of-sample R-squared**: This is the R-squared value on the test data (`pokeaman_test`), which gives an indication of how well the model generalizes to unseen data.
# 5. **Collecting Results**: Both metrics are collected in lists during each iteration.
# 6. **Visualization**: The results are visualized with two lines, one representing in-sample R-squared and the other representing out-of-sample R-squared, across 100 iterations.
#
# Meaning of Results:
# - **In-sample R-squared**: This value reflects how well the model fits the training data. It typically shows a higher value, as the model is optimized for the training data.
# - **Out-of-sample R-squared**: This value is more important as it reflects how well the model generalizes to new, unseen data. A significant difference between in-sample and out-of-sample R-squared suggests **overfitting**, where the model performs well on the training data but fails to generalize to the test data.
#
# The **purpose of this demonstration** is to illustrate how model performance can vary across multiple train-test splits and how the generalizability of a model can be assessed by comparing in-sample and out-of-sample performance. By visualizing this across many iterations, you get a sense of how stable the model's performance is and whether it is overly tuned to the training data or if it can generalize well to unseen data.

# %% [markdown]
# ### Question 9

# %%
model7_gen1_predict_future = smf.ols(formula=model7_linear_form,
                                   data=pokeaman[pokeaman.Generation==1])
model7_gen1_predict_future_fit = model7_gen1_predict_future.fit()
print("'In sample' R-squared:    ", model7_fit.rsquared, "(original)")
y = pokeaman_test.HP
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model7)[0,1]**2, "(original)")
print("'In sample' R-squared:    ", model7_gen1_predict_future_fit.rsquared, "(gen1_predict_future)")
y = pokeaman[pokeaman.Generation!=1].HP
yhat = model7_gen1_predict_future_fit.predict(pokeaman[pokeaman.Generation!=1])
print("'Out of sample' R-squared:", np.corrcoef(y,yhat)[0,1]**2, "(gen1_predict_future)")
# Out:
# 'In sample' R-squared:     0.37818209127432456 (original)
# 'Out of sample' R-squared: 0.00018905947734540018 (original)
# 'In sample' R-squared:     0.5726118179916575 (gen1_predict_future)
# 'Out of sample' R-squared: 0.11151363354803218 (gen1_predict_future)

# %%
model7_gen1to5_predict_future = smf.ols(formula=model7_linear_form,
                                   data=pokeaman[pokeaman.Generation!=6])
model7_gen1to5_predict_future_fit = model7_gen1to5_predict_future.fit()
print("'In sample' R-squared:    ", model7_fit.rsquared, "(original)")
y = pokeaman_test.HP
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model7)[0,1]**2, "(original)")
print("'In sample' R-squared:    ", model7_gen1to5_predict_future_fit.rsquared, "(gen1to5_predict_future)")
y = pokeaman[pokeaman.Generation==6].HP
yhat = model7_gen1to5_predict_future_fit.predict(pokeaman[pokeaman.Generation==6])
print("'Out of sample' R-squared:", np.corrcoef(y,yhat)[0,1]**2, "(gen1to5_predict_future)")
# Out:
# 'In sample' R-squared:     0.37818209127432456 (original)
# 'Out of sample' R-squared: 0.00018905947734540018 (original)
# 'In sample' R-squared:     0.3904756578094535 (gen1to5_predict_future)
# 'Out of sample' R-squared: 0.23394915464343125 (gen1to5_predict_future)

# %%
model6_gen1_predict_future = smf.ols(formula=model6_linear_form,
                                   data=pokeaman[pokeaman.Generation==1])
model6_gen1_predict_future_fit = model6_gen1_predict_future.fit()
print("'In sample' R-squared:    ", model6_fit.rsquared, "(original)")
y = pokeaman_test.HP
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model6)[0,1]**2, "(original)")
print("'In sample' R-squared:    ", model6_gen1_predict_future_fit.rsquared, "(gen1_predict_future)")
y = pokeaman[pokeaman.Generation!=1].HP
yhat = model6_gen1_predict_future_fit.predict(pokeaman[pokeaman.Generation!=1])
print("'Out of sample' R-squared:", np.corrcoef(y,yhat)[0,1]**2, "(gen1_predict_future)")
# Out:
# 'In sample' R-squared:     0.3326310334310908 (original)
# 'Out of sample' R-squared: 0.0003901627672308394 (original)
# 'In sample' R-squared:     0.4433880517727282 (gen1_predict_future)
# 'Out of sample' R-squared: 0.1932858534276128 (gen1_predict_future)

# %%
model6_gen1to5_predict_future = smf.ols(formula=model6_linear_form,
                                   data=pokeaman[pokeaman.Generation!=6])
model6_gen1to5_predict_future_fit = model6_gen1to5_predict_future.fit()
print("'In sample' R-squared:    ", model6_fit.rsquared, "(original)")
y = pokeaman_test.HP
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model6)[0,1]**2, "(original)")
print("'In sample' R-squared:    ", model6_gen1to5_predict_future_fit.rsquared, "(gen1to5_predict_future)")
y = pokeaman[pokeaman.Generation==6].HP
yhat = model6_gen1to5_predict_future_fit.predict(pokeaman[pokeaman.Generation==6])
print("'Out of sample' R-squared:", np.corrcoef(y,yhat)[0,1]**2, "(gen1to5_predict_future)")
# Out:
# 'In sample' R-squared:     0.3326310334310908 (original)
# 'Out of sample' R-squared: 0.0003901627672308394 (original)
# 'In sample' R-squared:     0.33517279824114776 (gen1to5_predict_future)
# 'Out of sample' R-squared: 0.26262690178799936 (gen1to5_predict_future)

# %% [markdown]
# This illustration is designed to explore how well the models (model6 and model7) generalize when trained on specific subsets of Pokémon generations and tested on others. Specifically:
#
# - The in-sample R-squared measures how well each model explains the variance in HP for the data it was trained on. High in-sample R-squared indicates a good fit for the training data.
#
# - The out-of-sample R-squared assesses the model's ability to generalize to data it has not seen before. This is calculated by using the model trained on one generation(s) and predicting for other generations. A high out-of-sample R-squared value indicates that the model generalizes well to new, unseen data.
#
# The four blocks show how the model trained on Generation 1 data performs on other generations and how the model trained on Generations 1 to 5 performs on Generation 6. By comparing in-sample and out-of-sample R-squared values, you can see if the model is overfitting or underfitting, and how well it is able to predict for Pokémon from different generations. If there's a large difference between in-sample and out-of-sample R-squared, it suggests that the model is overfitting (too tailored to the training data and not generalizing well).

# %% [markdown]
# ### Sumamary of Interactions for Q5-Q9
#
# Transcript Log: https://chatgpt.com/share/6735458e-2f44-8012-b8a6-c8c32f1ff82b
#
# 1. **Initial Model Development and Extension**:
#    - We started by discussing incremental model expansions, moving from simple linear forms (model3 and model4) to more complex interactions (model5, model6, and model7). These expansions included interaction terms and centered/scaled predictors to improve model interpretability and reduce multicollinearity, as seen in the drop in the condition number from 2,340,000,000 to 15.4.
#
# 2. **In-sample and Out-of-sample Performance Evaluation**:
#    - We implemented loops to visualize the in-sample and out-of-sample R-squared values across multiple model realizations. This demonstrated model stability and helped understand prediction variance without seeding. The loop generated a roughly symmetric distribution, indicating balanced model performance across datasets.
#
# 3. **Generational Prediction Analysis**:
#    - Four main blocks of code were used to assess models 6 and 7 on different Pokémon generations, training on subsets of Generations 1 to 5 and testing on others. This approach evaluated the model's ability to generalize across generational differences, with specific attention to in-sample vs. out-of-sample R-squared values to highlight potential overfitting or underfitting issues.
#
# 4. **Key Insights and Model Generalization**:
#    - The final analysis highlighted insights on generalizability and the effect of training on different generational data. High in-sample R-squared values with lower out-of-sample scores suggested areas where the models were too specific to the training generations, thereby informing future directions for enhancing model robustness across Pokémon generations.
